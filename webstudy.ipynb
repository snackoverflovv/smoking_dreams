# %%
# !pip install fastapi uvicorn holidays
# !pip install streamlit holidays ipywidgets
# Out:
# Requirement already satisfied: fastapi in c:\users\acoto\anaconda3\lib\site-packages (0.128.0)
# Requirement already satisfied: uvicorn in c:\users\acoto\anaconda3\lib\site-packages (0.40.0)
# Requirement already satisfied: holidays in c:\users\acoto\anaconda3\lib\site-packages (0.87)
# Requirement already satisfied: starlette<0.51.0,>=0.40.0 in c:\users\acoto\anaconda3\lib\site-packages (from fastapi) (0.50.0)
# Requirement already satisfied: pydantic>=2.7.0 in c:\users\acoto\anaconda3\lib\site-packages (from fastapi) (2.12.5)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\acoto\anaconda3\lib\site-packages (from fastapi) (4.15.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\acoto\anaconda3\lib\site-packages (from fastapi) (0.0.4)
# Requirement already satisfied: click>=7.0 in c:\users\acoto\anaconda3\lib\site-packages (from uvicorn) (8.0.4)
# Requirement already satisfied: h11>=0.8 in c:\users\acoto\anaconda3\lib\site-packages (from uvicorn) (0.16.0)
# Requirement already satisfied: python-dateutil<3,>=2.9.0.post0 in c:\users\acoto\anaconda3\lib\site-packages (from holidays) (2.9.0.post0)
# Requirement already satisfied: colorama in c:\users\acoto\anaconda3\lib\site-packages (from click>=7.0->uvicorn) (0.4.6)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\acoto\anaconda3\lib\site-packages (from pydantic>=2.7.0->fastapi) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\acoto\anaconda3\lib\site-packages (from pydantic>=2.7.0->fastapi) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\acoto\anaconda3\lib\site-packages (from pydantic>=2.7.0->fastapi) (0.4.2)
# Requirement already satisfied: six>=1.5 in c:\users\acoto\anaconda3\lib\site-packages (from python-dateutil<3,>=2.9.0.post0->holidays) (1.16.0)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\acoto\anaconda3\lib\site-packages (from starlette<0.51.0,>=0.40.0->fastapi) (4.12.0)
# Requirement already satisfied: idna>=2.8 in c:\users\acoto\anaconda3\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.51.0,>=0.40.0->fastapi) (3.4)
# Collecting streamlit
#   Obtaining dependency information for streamlit from https://files.pythonhosted.org/packages/c0/95/6b7873f0267973ebd55ba9cd33a690b35a116f2779901ef6185a0e21864d/streamlit-1.52.2-py3-none-any.whl.metadata
#   Downloading streamlit-1.52.2-py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: holidays in c:\users\acoto\anaconda3\lib\site-packages (0.87)
# Requirement already satisfied: ipywidgets in c:\users\acoto\anaconda3\lib\site-packages (8.0.4)
# Collecting altair!=5.4.0,!=5.4.1,<7,>=4.0 (from streamlit)
#   Obtaining dependency information for altair!=5.4.0,!=5.4.1,<7,>=4.0 from https://files.pythonhosted.org/packages/db/33/ef2f2409450ef6daa61459d5de5c08128e7d3edb773fefd0a324d1310238/altair-6.0.0-py3-none-any.whl.metadata
#   Downloading altair-6.0.0-py3-none-any.whl.metadata (11 kB)
# Collecting blinker<2,>=1.5.0 (from streamlit)
#   Obtaining dependency information for blinker<2,>=1.5.0 from https://files.pythonhosted.org/packages/10/cb/f2ad4230dc2eb1a74edf38f1a38b9b52277f75bef262d8908e60d957e13c/blinker-1.9.0-py3-none-any.whl.metadata
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting cachetools<7,>=4.0 (from streamlit)
#   Obtaining dependency information for cachetools<7,>=4.0 from https://files.pythonhosted.org/packages/2c/fc/1d7b80d0eb7b714984ce40efc78859c022cd930e402f599d8ca9e39c78a4/cachetools-6.2.4-py3-none-any.whl.metadata
#   Downloading cachetools-6.2.4-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: click<9,>=7.0 in c:\users\acoto\anaconda3\lib\site-packages (from streamlit) (8.0.4)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\acoto\anaconda3\lib\site-packages (from streamlit) (1.24.3)
# Requirement already satisfied: packaging>=20 in c:\users\acoto\anaconda3\lib\site-packages (from streamlit) (23.1)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\acoto\anaconda3\lib\site-packages (from streamlit) (2.0.3)
# Requirement already satisfied: pillow<13,>=7.1.0 in c:\users\acoto\anaconda3\lib\site-packages (from streamlit) (10.0.1)
# Collecting protobuf<7,>=3.20 (from streamlit)
#   Obtaining dependency information for protobuf<7,>=3.20 from https://files.pythonhosted.org/packages/64/20/4d50191997e917ae13ad0a235c8b42d8c1ab9c3e6fd455ca16d416944355/protobuf-6.33.2-cp310-abi3-win_amd64.whl.metadata
#   Downloading protobuf-6.33.2-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\acoto\anaconda3\lib\site-packages (from streamlit) (11.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\acoto\anaconda3\lib\site-packages (from streamlit) (2.31.0)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\acoto\anaconda3\lib\site-packages (from streamlit) (8.2.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\acoto\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\users\acoto\anaconda3\lib\site-packages (from streamlit) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\acoto\anaconda3\lib\site-packages (from streamlit) (2.1.6)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit)
#   Obtaining dependency information for gitpython!=3.1.19,<4,>=3.0.7 from https://files.pythonhosted.org/packages/01/61/d4b89fec821f72385526e1b9d9a3a0385dda4a72b206d28049e2c7cd39b8/gitpython-3.1.45-py3-none-any.whl.metadata
#   Downloading gitpython-3.1.45-py3-none-any.whl.metadata (13 kB)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Obtaining dependency information for pydeck<1,>=0.8.0b4 from https://files.pythonhosted.org/packages/ab/4c/b888e6cf58bd9db9c93f40d1c6be8283ff49d88919231afe93a6bcf61626/pydeck-0.9.1-py2.py3-none-any.whl.metadata
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in c:\users\acoto\anaconda3\lib\site-packages (from streamlit) (6.3.2)
# Requirement already satisfied: python-dateutil<3,>=2.9.0.post0 in c:\users\acoto\anaconda3\lib\site-packages (from holidays) (2.9.0.post0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\acoto\anaconda3\lib\site-packages (from ipywidgets) (6.25.0)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\acoto\anaconda3\lib\site-packages (from ipywidgets) (8.15.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\acoto\anaconda3\lib\site-packages (from ipywidgets) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=4.0 in c:\users\acoto\anaconda3\lib\site-packages (from ipywidgets) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in c:\users\acoto\anaconda3\lib\site-packages (from ipywidgets) (3.0.5)
# Requirement already satisfied: jinja2 in c:\users\acoto\anaconda3\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\acoto\anaconda3\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.17.3)
# Collecting narwhals>=1.27.1 (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit)
#   Obtaining dependency information for narwhals>=1.27.1 from https://files.pythonhosted.org/packages/79/3e/b8ecc67e178919671695f64374a7ba916cf0adbf86efedc6054f38b5b8ae/narwhals-2.14.0-py3-none-any.whl.metadata
#   Downloading narwhals-2.14.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: colorama in c:\users\acoto\anaconda3\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Obtaining dependency information for gitdb<5,>=4.0.1 from https://files.pythonhosted.org/packages/a0/61/5c78b91c3143ed5c14207f463aecfc8f9dbb5092fb2869baf37c273b2705/gitdb-4.0.12-py3-none-any.whl.metadata
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: comm>=0.1.1 in c:\users\acoto\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\acoto\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\acoto\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (7.4.9)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\acoto\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (5.3.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\acoto\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\acoto\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.6)
# Requirement already satisfied: psutil in c:\users\acoto\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (5.9.0)
# Requirement already satisfied: pyzmq>=20 in c:\users\acoto\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (23.2.0)
# Requirement already satisfied: backcall in c:\users\acoto\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: decorator in c:\users\acoto\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\acoto\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.18.1)
# Requirement already satisfied: pickleshare in c:\users\acoto\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\acoto\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\acoto\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\acoto\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\acoto\anaconda3\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\acoto\anaconda3\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\acoto\anaconda3\lib\site-packages (from python-dateutil<3,>=2.9.0.post0->holidays) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\acoto\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\acoto\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\acoto\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\acoto\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2023.11.17)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Obtaining dependency information for smmap<6,>=3.0.1 from https://files.pythonhosted.org/packages/04/be/d09147ad1ec7934636ad912901c5fd7667e1c858e19d355237db0d0cd5e4/smmap-5.0.2-py3-none-any.whl.metadata
#   Downloading smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\acoto\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\acoto\anaconda3\lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.1.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\acoto\anaconda3\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\acoto\anaconda3\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.18.0)
# Requirement already satisfied: entrypoints in c:\users\acoto\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\acoto\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\acoto\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets) (305.1)
# Requirement already satisfied: wcwidth in c:\users\acoto\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets) (0.2.5)
# Requirement already satisfied: executing in c:\users\acoto\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\acoto\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\acoto\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Downloading streamlit-1.52.2-py3-none-any.whl (9.0 MB)
#    ---------------------------------------- 0.0/9.0 MB ? eta -:--:--
#    ---------------------------------------- 0.1/9.0 MB 2.2 MB/s eta 0:00:04
#     --------------------------------------- 0.2/9.0 MB 2.4 MB/s eta 0:00:04
#    - -------------------------------------- 0.4/9.0 MB 3.0 MB/s eta 0:00:03
#    -- ------------------------------------- 0.5/9.0 MB 2.9 MB/s eta 0:00:03
#    -- ------------------------------------- 0.6/9.0 MB 2.7 MB/s eta 0:00:04
#    -- ------------------------------------- 0.6/9.0 MB 2.6 MB/s eta 0:00:04
#    --- ------------------------------------ 0.7/9.0 MB 2.5 MB/s eta 0:00:04
#    --- ------------------------------------ 0.8/9.0 MB 2.3 MB/s eta 0:00:04
#    --- ------------------------------------ 0.8/9.0 MB 2.2 MB/s eta 0:00:04
#    --- ------------------------------------ 0.9/9.0 MB 2.1 MB/s eta 0:00:04
#    --- ------------------------------------ 0.9/9.0 MB 2.1 MB/s eta 0:00:04
#    ---- ----------------------------------- 0.9/9.0 MB 1.8 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.0/9.0 MB 1.7 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.1/9.0 MB 1.7 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.1/9.0 MB 1.6 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.2/9.0 MB 1.6 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.2/9.0 MB 1.6 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.3/9.0 MB 1.7 MB/s eta 0:00:05
#    ------ --------------------------------- 1.5/9.0 MB 1.8 MB/s eta 0:00:05
#    ------- -------------------------------- 1.7/9.0 MB 1.9 MB/s eta 0:00:04
#    ------- -------------------------------- 1.8/9.0 MB 1.9 MB/s eta 0:00:04
#    -------- ------------------------------- 2.0/9.0 MB 2.0 MB/s eta 0:00:04
#    --------- ------------------------------ 2.1/9.0 MB 2.1 MB/s eta 0:00:04
#    --------- ------------------------------ 2.2/9.0 MB 2.0 MB/s eta 0:00:04
#    --------- ------------------------------ 2.2/9.0 MB 2.0 MB/s eta 0:00:04
#    ---------- ----------------------------- 2
9 MB 2.9 MB/s eta 0:00:02
#    ---------------------- ----------------- 3.9/6.9 MB 3.0 MB/s eta 0:00:02
#    ----------------------- ---------------- 4.0/6.9 MB 3.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.1/6.9 MB 3.0 MB/s eta 0:00:01
#    ------------------------ --------------- 4.2/6.9 MB 2.9 MB/s eta 0:00:01
#    ------------------------- -------------- 4.4/6.9 MB 2.9 MB/s eta 0:00:01
#    -------------------------- ------------- 4.6/6.9 MB 3.0 MB/s eta 0:00:01
#    -------------------------- ------------- 4.6/6.9 MB 2.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 4.9/6.9 MB 3.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.0/6.9 MB 3.0 MB/s eta 0:00:01
#    ------------------------------ --------- 5.2/6.9 MB 3.0 MB/s eta 0:00:01
#    ------------------------------ --------- 5.3/6.9 MB 3.0 MB/s eta 0:00:01
#    -------------------------------- ------- 5.5/6.9 MB 3.0 MB/s eta 0:00:01
#    -------------------------------- ------- 5.6/6.9 MB 3.0 MB/s eta 0:00:01
#    -------------------------------- ------- 5.6/6.9 MB 3.0 MB/s eta 0:00:01
#    --------------------------------- ------ 5.7/6.9 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 5.9/6.9 MB 3.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.1/6.9 MB 3.0 MB/s eta 0:00:01
#    ------------------------------------ --- 6.2/6.9 MB 3.0 MB/s eta 0:00:01
#    ------------------------------------ --- 6.3/6.9 MB 3.0 MB/s eta 0:00:01
#    ------------------------------------- -- 6.5/6.9 MB 3.0 MB/s eta 0:00:01
#    -------------------------------------- - 6.7/6.9 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  6.8/6.9 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  6.9/6.9 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 6.9/6.9 MB 2.9 MB/s eta 0:00:00
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
#    ---------------------------------------- 0.0/62.8 kB ? eta -:--:--
#    ---------------------------------------- 62.8/62.8 kB ? eta 0:00:00
# Downloading narwhals-2.14.0-py3-none-any.whl (430 kB)
#    ---------------------------------------- 0.0/430.8 kB ? eta -:--:--
#    --------------- ----------------------- 174.1/430.8 kB 10.2 MB/s eta 0:00:01
#    -------------------------------- ------- 348.2/430.8 kB 3.6 MB/s eta 0:00:01
#    ------------------------------------- -- 399.4/430.8 kB 3.1 MB/s eta 0:00:01
#    ---------------------------------------- 430.8/430.8 kB 3.0 MB/s eta 0:00:00
# Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Installing collected packages: smmap, protobuf, narwhals, cachetools, blinker, pydeck, gitdb, altair, gitpython, streamlit
# Successfully installed altair-6.0.0 blinker-1.9.0 cachetools-6.2.4 gitdb-4.0.12 gitpython-3.1.45 narwhals-2.14.0 protobuf-6.33.2 pydeck-0.9.1 smmap-5.0.2 streamlit-1.52.2

# %%
from datetime import date, timedelta
import holidays

# 대한민국 공휴일
KR_HOLIDAYS = holidays.KR()

# %%
def is_holiday(d: date, extra_holidays: set[date] | None = None) -> bool:
    """
    휴일 여부 판별
    - 토요일 / 일요일
    - 국가 공휴일
    - 부대 전투휴무 (extra_holidays)
    """
    if extra_holidays is None:
        extra_holidays = set()
        
    return (
        d.weekday() >= 5  # 토, 일
        or d in KR_HOLIDAYS
        or d in extra_holidays
    )

# %%
def calculate_rest_period(
    leave_start: date,
    leave_days: int,
    extra_holidays: set[date] | None = None
) -> dict:
    """
    휴가 시작일 + 휴가 일수 → 실제 연속 휴식 기간 계산
    """
    if extra_holidays is None:
        extra_holidays = set()
        
    leave_end = leave_start + timedelta(days=leave_days - 1)

    # 앞쪽 확장
    rest_start = leave_start
    while is_holiday(rest_start - timedelta(days=1), extra_holidays):
        rest_start -= timedelta(days=1)

    # 뒤쪽 확장
    rest_end = leave_end
    while is_holiday(rest_end + timedelta(days=1), extra_holidays):
        rest_end += timedelta(days=1)

    return {
        "leave_start": leave_start,
        "leave_end": leave_end,
        "rest_start": rest_start,
        "rest_end": rest_end,
        "leave_days": leave_days,
        "total_rest_days": (rest_end - rest_start).days + 1
    }

# %%
def recommend_best_vacations(
    search_start: date,
    search_end: date,
    leave_days: int,
    extra_holidays: set[date] | None = None,
    top_k: int = 3
) -> list[dict]:
    """
    탐색 기간 내에서 가장 효율 좋은 휴가 TOP K 추천
    """
    if extra_holidays is None:
        extra_holidays = set()
        
    results = []
    cur = search_start

    while cur + timedelta(days=leave_days - 1) <= search_end:
        result = calculate_rest_period(
            leave_start=cur,
            leave_days=leave_days,
            extra_holidays=extra_holidays
        )
        results.append(result)
        cur += timedelta(days=1)

    # 실제 휴식 일수 기준 정렬
    results.sort(key=lambda x: x["total_rest_days"], reverse=True)
    return results[:top_k]
